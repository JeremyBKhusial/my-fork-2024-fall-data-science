# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = 'data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
df_food
#There are 125 rows and 61 columns
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
df_food = df_food[['Gender', 'calories_day', 'weight']]
df_food
# Out:
#      Gender  calories_day                    weight
# 0         2           NaN                       187
# 1         1           3.0                       155
# 2         1           4.0  I'm not answering this.
# 3         1           3.0             Not sure, 240
# 4         1           2.0                       190
# ..      ...           ...                       ...
# 120       1           4.0                       156
# 121       1           2.0                       180
# 122       1           NaN                       120
# 123       2           4.0                       135
# 124       1           NaN                       135
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.

df_food.isnull().sum()
# Out:
# Gender           0
# calories_day    19
# weight           2
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
df_food_dropped = df_food.dropna()
df_food_dropped
# Out:
#      Gender  calories_day  weight
# 1         1           3.0   155.0
# 4         1           2.0   190.0
# 5         1           3.0   190.0
# 6         2           3.0   180.0
# 7         1           3.0   137.0
# ..      ...           ...     ...
# 118       1           3.0   140.0
# 119       2           3.0   185.0
# 120       1           4.0   156.0
# 121       1           2.0   180.0
# 123       2           4.0   135.0
#
# [101 rows x 3 columns]

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
df_food['weight'] = pd.to_numeric(df_food['weight'], errors = 'coerce')
df_food_dropped
# Out:
# C:\Users\hijer\AppData\Local\Temp\ipykernel_56784\120855064.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_food['weight'] = pd.to_numeric(df_food['weight'], errors = 'coerce')
#      Gender  calories_day  weight
# 1         1           3.0   155.0
# 4         1           2.0   190.0
# 5         1           3.0   190.0
# 6         2           3.0   180.0
# 7         1           3.0   137.0
# ..      ...           ...     ...
# 118       1           3.0   140.0
# 119       2           3.0   185.0
# 120       1           4.0   156.0
# 121       1           2.0   180.0
# 123       2           4.0   135.0
#
# [101 rows x 3 columns]

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!

df_food_dropped.to_csv('data/df_food_clean.csv')

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
df_salary = pd.read_csv('data\Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv', sep=',')

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
df_salary.to_csv('data/df_salary.csv', index= False)
df_salary = pd.read_csv('data/df_salary.csv')
df_salary.shape
# Out:
# (28062, 19)

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
del df_salary['Unnamed: 0']
df_salary.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                object
# How old are you?                                                                                                                                                                                                                         object
# What industry do you work in?                                                                                                                                                                                                            object
# Job title                                                                                                                                                                                                                                object
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
df_salary.columns = ['timestamp', 'age', 'industry', 'title', 'title_context', 'salary', 'additional_compensation', 'currency', 'other_currency', 'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe', 'highest_education_completed',	'gender', 'race']

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
df_salary['industry'].value_counts()
# Out:
# industry
# Computing or Tech                          4699
# Education (Higher Education)               2464
# Nonprofits                                 2419
# Health care                                1896
# Government and Public Administration       1889
#                                            ...
# Gaming (Gambling)                             1
# Regulatory Affairs- nutraceuticals            1
# Manufacturing : corporate admin support       1
# Real Estate Investment Support                1
# Wine & Spirits                                1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
#df_salary_tech = df_salary[df_salary['industry']]
#host_names = df['host_name'].isin(['Michael', 'David', 'John', 'Daniel'])
salary_tech = df_salary['industry'].isin(['Computing or Tech', 'Education (Higher Education)', 'Nonprofits', 'Health care', 'Government and Public Administration'])
df_salary_tech = df_salary[salary_tech]

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 

df_salary_tech['industry'].value_counts()
# Out:
# industry
# Computing or Tech                       4699
# Education (Higher Education)            2464
# Nonprofits                              2419
# Health care                             1896
# Government and Public Administration    1889
# Name: count, dtype: int64

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!
# df_salary['currency'].isin(['USD'])
c1 = df_salary['currency'] == 'USD'
df_salary_USD = df_salary[c1]
df_salary_USD
# c1 = df['neighbourhood'] == 'Williamsburg'

# # Second select condition.
# c2 = df['room_type'] == 'Private room'

# # Set equal to one when both conditions are true, and zero when not true.
# df['private_room_in_williamsburg'] =  np.where( c1 & c2, 1, 0 )

# # Sanity check to view if our assignment worked correctly.
# select_statement = df['private_room_in_williamsburg'] == 1

# new_df = df[  select_statement ]

# df['select_statement'] = select_statement
# Out:
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 5      4/27/2021 11:02:46  25-34   Education (Higher Education)
# ...                   ...    ...                            ...
# 28052   7/3/2024 14:02:01  25-34              Computing or Tech
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
# 28059  7/24/2024 12:22:58  18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45  18-24              Computing or Tech
#
#                                         title title_context  salary  \
# 0          Research and Instruction Librarian           NaN  55,000
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
s = df_salary_USD['country'].value_counts()
s.head(30)
# Out:
# country
# United States                8989
# USA                          7922
# US                           2606
# United States                 667
# U.S.                          580
# USA                           467
# Usa                           448
# United States of America      427
# United states                 208
# usa                           183
# united states                 116
# Us                            105
# U.S.A.                         45
# United States of America       44
# us                             37
# U.S                            22
# America                        21
# United State                   19
# US                             18
# Usa                            18
# U.S.                           17
# Canada                         16
# Unites States                  13
# United states                  13
# U.S.A                           9
# United Stated                   9
# Australia                       8
# ...

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.
usa_replacement = ['USA', 'US', 'U.S.', 'Usa', 'United States of America']
def fix_us_name(replacements):
    if replacements in usa_replacement:
        return 'United States'
    else:
        return replacements
df_salary_USD['country'] = df_salary_USD['country'].apply(fix_us_name)

df_salary_USD
# Out:
# C:\Users\hijer\AppData\Local\Temp\ipykernel_56784\3938234046.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_USD['country'] = df_salary_USD['country'].apply(fix_us_name)
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 5      4/27/2021 11:02:46  25-34   Education (Higher Education)
# ...                   ...    ...                            ...
# 28052   7/3/2024 14:02:01  25-34              Computing or Tech
# ...

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
s = df_salary_USD['country'].value_counts()
s.head(30)
# Out:
# country
# United States                20972
# United States                  667
# USA                            467
# United states                  208
# usa                            183
# united states                  116
# Us                             105
# U.S.A.                          45
# United States of America        44
# us                              37
# U.S                             22
# America                         21
# United State                    19
# US                              18
# Usa                             18
# U.S.                            17
# Canada                          16
# Unites States                   13
# United states                   13
# United Stated                    9
# U.S.A                            9
# Australia                        8
# Israel                           7
# UNITED STATES                    7
# The United States                7
# United Kingdom                   7
# ...

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.
# df_salary_USD['country'] = df_salary_USD['country'].str.replace(r'\b(us|unites states|u\.s\.a\.|u\.s\.|united states)\b', 'United States', case=False, regex=True)
# df_salary_USD['country'].value_counts()
# I tried the way above but i ran into a weird error where I got United States, United StatesA, and UnitedStatesa repeating instead of just United States
#
# 
#  us_name_types = df_salary_USD[df_salary_USD['country'].str.contains('U|S|u|s|America')]['country'].unique()
# us_name_types
# This way above also gives another error and I get entries that I dont understand
# Out:
# array(['United States', 'United StatesA', 'United Statesa',
#        'United States ', 'United StatesA ', 'United States of America ',
#        'U.S>', 'ISA', 'United State', 'United Kingdom', 'America',
#        'United States of america', 'Bermuda', 'The United States',
#        'United State of America', 'United Stated', 'Kuwait', 'Sri lanka',
#        'Contracts', 'United StatesA-- Virgin Islands', 'United Statws',
#        'U.S',
#        "We don't get raises, we get quarterly bonUnited Stateses, but they periodically asses income in the area you work, so I got a raise becaUnited Statese a 3rd party assessment showed I was paid too little for the area we were located",
#        'United Statesa ', 'U. S. ', 'United Sates',
#        'United States of American ', 'Uniited States',
#        'Worldwide (based in United States but short term trips aroudn the world)',
#        'United Sates of America',
# ...

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
df_salary_USD.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\hijer\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\hijer\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\hijer\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.
df_salary_USD['salary'] = pd.to_numeric(df_salary_USD['salary'], errors= 'coerce')
df_salary_USD
# Out:
# C:\Users\hijer\AppData\Local\Temp\ipykernel_56784\3661748317.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_USD['salary'] = pd.to_numeric(df_salary_USD['salary'], errors= 'coerce')
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 5      4/27/2021 11:02:46  25-34   Education (Higher Education)
# ...                   ...    ...                            ...
# 28052   7/3/2024 14:02:01  25-34              Computing or Tech
# ...

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!

df_salary_USD.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
#                                    min       mean         max
# state
# Alabama, South Carolina      5000000.0  5000000.0   5000000.0
# Alaska                         47840.0   737319.2  10000000.0
# Michigan, Texas, Washington   340000.0   340000.0    340000.0
# California, Oregon            200000.0   200000.0    200000.0
# California, Colorado          176000.0   176000.0    176000.0
# ...                                ...        ...         ...
# North Carolina, Utah               NaN        NaN         NaN
# Ohio, Washington                   NaN        NaN         NaN
# Ohio, Wyoming                      NaN        NaN         NaN
# Texas, Virginia                    NaN        NaN         NaN
# Utah, Vermont                      NaN        NaN         NaN
#
# [133 rows x 3 columns]

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

year_pattern = r'202[1-3]'
df_further_filtered_salary = df_salary_USD[df_salary_USD['timestamp'].str.contains(year_pattern, regex = True)]
salary = df_further_filtered_salary.groupby('state')['salary'].agg(['min','mean','max'])
salary['mean'] = salary['mean'].round()
salary
# I am not sure why i am getting NAN values but i ran out of time to debug
# Out:
#                                    min     mean        max
# state
# Alabama                            0.0  68424.0   350000.0
# Alabama, California            29120.0  29120.0    29120.0
# Alabama, District of Columbia      NaN      NaN        NaN
# Alabama, Kansas                    NaN      NaN        NaN
# Alabama, Minnesota, Nevada         NaN      NaN        NaN
# ...                                ...      ...        ...
# Virginia                          57.0  96247.0  1300000.0
# Washington                        72.0  98022.0   300000.0
# West Virginia                      0.0  52754.0   120000.0
# Wisconsin                          1.0  83001.0   920000.0
# Wyoming                        42500.0  59906.0    98000.0
#
# [131 rows x 3 columns]

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
